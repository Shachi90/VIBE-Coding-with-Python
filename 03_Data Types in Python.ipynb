# %% [markdown]
# ## DataType : String

# %%
george_v = "His Majesty George V, by the Grace Of God, " \
"Of the United Kingdom Of Great Britain and " \
"Ireland and of the British Dominions beyond " \
"the Seas, King, Defender Of the Faith, Emperor Of India"
gandhi = 'Mohandas Karamchand Gandhi'
john_f_kennedy = 'JFK '

print(len(george_v),'characters is much too long of a name!')
print(len(gandhi),'characters is better...')
print(len(john_f_kennedy), 'characters is short enough.')
# Out:
# 185 characters is much too long of a name!
# 26 characters is better...
# 4 characters is short enough.

# %%
alphabet =  'ABCDEFGHIJKLMNOPQRSTUVWXYZ '
print (alphabet [0], alphabet [1],alphabet [25] )
# Out:
# A B Z

# %%
print(alphabet[-1], alphabet[-2], alphabet[-26])
# Out:
# Z Y A

# %%
alphabet ='abcdefghijklmnopqrstuvwxyz'

# Change to upper case

alphabet[0]= 'A'#  Invalid: Cannot change character
alphabet[1] = 'B' # Inval id: Cannot change character

print('Alphabet:', alphabet)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 alphabet ='abcdefghijklmnopqrstuvwxyz'
#       3 # Change to upper case
# ----> 5 alphabet[0]= 'A'#  Inval id: Cannot change character
#       6 alphabet[1] = 'B' # Inval id: Cannot change character
#       8 print('Alphabet:', alphabet)
#
# TypeError: 'str' object does not support item assignment

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'

# Change to upper case
alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

print('Alphabet:', alphabet)
# Out:
# Alphabet: ABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
string_l = 'abc'
string_2 = '123'
concatenated_string = string_l + string_2
print('Easy as' + concatenated_string)
# Out:
# Easy asabc123

# %% [markdown]
# ## Datatype : List

# %%
# Some of the most expensive cars in the world
lamborghini_veneno = 3900000 # $3.9 million!
bugatti_veyron = 2400000     # $2.4 million!
aston_martin_one77 = 1850000 # $1.85 million!

prices = [lamborghini_veneno, bugatti_veyron, aston_martin_one77]

print('Lamborghini Veneno:', prices[0],'dollars')
print('Bugatti Veyron Super Sport:', prices[1], 'dollars')
print('Aston Martin One-77:', prices[2], 'dollars')
# Out:
# Lamborghini Veneno: 3900000 dollars
# Bugatti Veyron Super Sport: 2400000 dollars
# Aston Martin One-77: 1850000 dollars

# %%
#Demonstrateing string concatenation and repetition
print('price list:', prices)
print()

#negative indexing from the end
print('prices[-1] (last element):', prices[-1])
print('prices[-2] (second to last element):', prices[-2])
print('prices[-3] (third to last element):', prices[-3])
print()

#comparison with positive indexing
print('Positive vs. Negative Indexing:')
print(f'prices[0] (first element)= {prices[0]} is the same as prices[-3] = {prices[-3]}')
print(f'prices[1] (second element)= {prices[1]} is the same as prices[-2] = {prices[-2]}')
print(f'prices[2] (third element)= {prices[2]} is the same as prices[-1] = {prices[-1]}')
# Out:
# price list: [3900000, 2400000, 1850000]
#
# prices[-1] (last element): 1850000
# prices[-2] (second to last element): 2400000
# prices[-3] (third to last element): 3900000
#
# Positive vs. Negative Indexing:
# prices[0] (first element)= 3900000 is the same as prices[-3] = 3900000
# prices[1] (second element)= 2400000 is the same as prices[-2] = 2400000
# prices[2] (third element)= 1850000 is the same as prices[-1] = 1850000

# %%
my_nums = [5, 12, 26]
print (my_nums)

# Update a list element
my_nums [ 1 ]= -28
print (my_nums)
# Out:
# [5, 12, 26]
# [5, -28, 26]

# %%
my_list = [10, 'bw']
print(my_list)
my_list. append( 'abc' )
print('After append:', my_list)

my_list.pop(1)
print( 'After pop: ' , my_list)

my_list.remove('abc')
print( 'After remove:', my_list)
# Out:
# [10, 'bw']
# After append: [10, 'bw', 'abc']
# After pop:  [10, 'abc']
# After remove: [10]

# %%
# Concatenating lists
house_prices = [380000, 900000, 8875000] + [225000]
print( 'There are', len(house_prices), 'prices in the list. ')

# Finding min, max
print( 'Cheapest house: ' ,min(house_prices))
print( 'Most expensive house: ' ,max(house_prices))
# Out:
# There are 4 prices in the list.
# Cheapest house:  225000
# Most expensive house:  8875000

# %% [markdown]
# Tuple

# %%
white_house_coordinates = (38.8977, 77.0366)
print('Coordinates:', white_house_coordinates)
print('Tuple length:', len(white_house_coordinates))
# Out:
# Coordinates: (38.8977, 77.0366)
# Tuple length: 2

# %%
# Access tuples via index
print( '\nLatitude: ' , white_house_coordinates [0] , 'north')
print( ' Longitude:', white_house_coordinates[1], 'west\n')
# Out:
# Latitude:  38.8977 north
#  Longitude: 77.0366 west

# %%
# Error. Tuples are immutable.
white_house_coordinates[0] = 40.7128 # Invalid: Cannot change tuple element
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Error. Tuples are immutable.
# ----> 2 white_house_coordinates[0] = 40.7128 # Invalid: Cannot change tuple element
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Set

# %%
# Create a set using the set() function.
nums1 = set([1,2,3])

# Create a setusing a set Literal.
nums2 = { 7,8,9 }

# Print the contents of the sets.
print (nums1)
print (nums2)
# Out:
# {1, 2, 3}
# {8, 9, 7}

# %%
# create sets
namesl = {'Pedro', 'Khan', 'Dean'}
names2 = {'Emilia','Kara','Tia'}

# Add element to set
namesl. add( 'Hyungu' )

print(namesl)
# Out:
# {'Khan', 'Hyungu', 'Pedro', 'Dean'}

# %%
# Add names 2 to names I
namesl.update(names2)

print (namesl)
# Out:
# {'Khan', 'Hyungu', 'Pedro', 'Kara', 'Dean', 'Tia', 'Emilia'}

# %%
# Add names2 to namesl
try:
    namesl.update(names2)
except NameError:
    namesl.update(nat1PS2)
print (namesl)
# Out:
# {'Hyungu', 'Pedro', 'Dean', 'Emilia', 'Khan', 'Kara', 'Tia'}

# %%
# Remove element from set
namesl. remove( 'Dean')
print(namesl)
# Out:
# {'Khan', 'Hyungu', 'Pedro', 'Kara,Tia', 'Emilia'}

# %%
# Clear all elements from set
names2. clear( )
print(names2)
# Out:
# set()

# %%
# Create sets
namesl ={'Corrin', 'Pedro', 'Khan', 'Dean'}
names2 ={'Emilia', 'Kara', 'Corrin','Tia'}
names3 ={'Karat', 'Kara', 'Karah', 'Khan'}
names4 ={'Khan', 'Dean', 'Pascale'}

# union namesl and names2
result_set = namesl. union (names2)

print( 'Union namesl and names2:\n', result_set)
# Out:
# Union namesl and names2:
#  {'Pedro', 'Dean', 'Corrin', 'Emilia', 'Khan', 'Kara', 'Tia'}

# %%
# Intersection btwn result set and names3
result_set = result_set. intersection (names3)
print( 'Intersection btwn result_set and names3:' , result_set)
# Out:
# Intersection btwn result_set and names3: {'Khan', 'Kara'}

# %%
# Difference btwn result _ set and names4
result_set = result_set. difference(names4)
print( 'Difference btwn result _ set and names4: ' , result_set)
# Out:
# Difference btwn result _ set and names4:  {'Kara'}

# %% [markdown]
# ## Dictinory

# %%
players = {
'Lionel Messi' : 10,
'Cristiano Ronaldo' : 7
}
print (players)

# %%
prices = {'apples': 1.99, 'oranges': 1.49}

print(f'The price of apple is {prices["apples"]}')

# %%
prices = {}Create empty dictionary
prices [ 'banana ' ] = 1.49 # Add new entry
print (prices)

# %%
prices ['banana']= 1.69 # Modify entry
print(prices)

# %%
del prices [ 'banana' ] # Remove entry
print (prices)
