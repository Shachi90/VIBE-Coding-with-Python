# %%
user_input =''
while user_input != 'q' :
      weight = int(input("Enter weight (in pounds):"))
      height = int(input("Enter height (in inches):"))
      print('Weight:')
      print('Height:')

bmi = (float (weight) / float(height * height))*703
print('BMI:', bmi)
print('(CDC: 18.6-24.9 normal)\n')
# Source www.cdc.gov

user_input = input("Enter any key ('q' to quit):")
# Out:
# Weight:
# Height:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 user_input =''
#       2 while user_input != 'q' :
# ----> 3       weight = int(input("Enter weight (in pounds):"))
#       4       height = int(input("Enter height (in inches):"))
#       5       print('Weight:')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
user_input = ''
while user_input != 'q':
    try:
        weight = int(input("Enter weight (in poundsd):"))
        height = int(input("Enter height (in inches):"))

        bmi = (float (weight) / float (height * height)) * 703
        print( 'BMI:', bmi)
        print('(CDS: 18.6-24.9 normal)\n')   # Source www.cds.gov
    except ValueError:
        print( 'Could not calculate health info.\n' )
    user_input = input("Enter any key ('q' to quit):")
# Out:
# BMI: 10.545
# (CDS: 18.6-24.9 normal)
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# Could not calculate health info.
#
# BMI: 10.545
# (CDS: 18.6-24.9 normal)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 try:
#       4     weight = int(input("Enter weight (in poundsd):"))
# ----> 5     height = int(input("Enter height (in inches):"))
#       7     bmi = (float (weight) / float (height * height)) * 703
#       8     print( 'BMI:', bmi)
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Multiple exception handling

# %%
user_input = ''
while user_input != 'q':
    try:
        weight = int(input("Enter weight (in poundsd):"))
        height = int(input("Enter height (in inches):"))

        bmi = (float (weight) / float (height * height)) * 703
        print( 'BMI:', bmi)
        print('(CDS: 18.6-24.9 normal)\n')   # Source www.cds.gov
    except ValueError:
        print( 'Could not calculate health info.\n' )
    except ZeroDivisionError:
        print( 'Invalid height entered. Must be > 0. ')

    user_input = input("Enter any key ('q' to quit):")
# Out:
# Invalid height entered. Must be > 0.

# %%
user_input = ' '
while user_input != 'q':
    try:
        weight = int(input('Enter weight (inpounds):'))
        if weight < 0:
          raise ValueError('Invalid weight.')
        height = int(input('Enter height (in inches):'))
        if height <= 0:
          raise ValueError('Invalid height.')
        print('Weight:', weight, 'Height:', height)
        bmi = (float(weight) * 703) / (float(height * height))
        print('BMI:', bmi)
        print('(CDC: 18.6-24.9 normal)\n')
        # Source www.cdc.gov
     except ValueError as excpt:
           print(excpt)
           print( 'Could not calculate health info.\n')
     user_input = input("Enter any key ('q' to quit):")
# Out:
#   File <string>:15
#     except ValueError as excpt:
#                                ^
# IndentationError: unindent does not match any outer indentation level

# %%
def get_weight():
   weight = int(input('Enter weight (in pounds):'))
   if weight < 0:
      raise ValueError('Invalid weight.')
   return weight

def get_height():
   height = int(input('Enter height (in inches):'))
   if height <= 0:
      raise ValueError('Invalid height.')
   return height

user_input = ''
while user_input != 'q':
   try:
      weight = get_weight()
      height = get_height()
      print('Weight:', weight, 'Height:', height)
      bmi = (float(weight) / float(height * height)) * 703
      print('BMI:',bmi)
      print ('CDC: 18.6-24.9 normal)\n')
      # Source www.cdc.gov

   except ValueError as excpt:
       print (excpt)
       print('could not calculate health info. \n,')

   user_input = input("Enter any key ('q' to quit):")
# Out:
# Weight: 100 Height: 20
# BMI: 175.75
# CDC: 18.6-24.9 normal)

# %%
def divide(a, b):
  z = -1
try:
    z = a / b
except ZeroDivisionError:
    print( 'Cannot divide by zero')
finally:
    print('Result is' , z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       3 try:
# ----> 4     z = a / b
#       5 except ZeroDivisionError:
#
# NameError: name 'a' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       6     print( 'Cannot divide by zero')
#       7 finally:
# ----> 8     print('Result is' , z)
#
# NameError: name 'z' is not defined

# %% [markdown]
# ## coustom exception

# %%
# Define a custom exception type
class LessThanZeroError( Exception) :
    def __init__(self,value) :
        self.value = value

my_num = int(input('Enter number:'))

if my_num < 0:
    raise LessThanZeroError('my_num must be greater than 0 ')
else:
    print('my_num: ', my_num)
# Out:
# ---------------------------------------------------------------------------
# LessThanZeroError                         Traceback (most recent call last)
# Cell In[25], line 9
#       6 my_num = int(input('Enter number:'))
#       8 if my_num < 0:
# ----> 9     raise LessThanZeroError('my_num must be greater than 0 ')
#      10 else:
#      11     print('my_num: ', my_num)
#
# LessThanZeroError: my_num must be greater than 0
