# %%
def calc_pizza_area():
    pi_val = 3.14159265

    pizza_diameter = 12.0
    pizza_radius = pizza_diameter / 2.0
    pizza_area = pi_val * pizza_radius * pizza_radius
    return pizza_area

print( '12. 0 inch pizza is' , calc_pizza_area(),'square inches.')
# Out:
# 12. 0 inch pizza is 113.09733540000002 square inches.

# %%
def  computer_square(num_to_square):
    return num_to_square * num_to_square

num_squared = computer_square(7)
print( '7 squared is ', num_squared)
# Out:
# 7 squared is  49

# %% [markdown]
# ### print function

# %%
def print_summary(oid,items,price):
    print( 'Order' ,oid)
    print( 'Items', items)
    print( 'Total:', price)

# %%
oid = 42
items = 3
price = 13.99
print_summary(oid,items,price)
# Out:
# Order 42
# Items 3
# Total: 13.99

# %%
def print_menu():
    print( '1.  Pizza')
    print( '2.  Pasta')
    print( '3.  Salad')
    print( '4.  Dessert')
quite_program = False
while not quite_program:
    print_menu()
    user_choice = input( 'Enter your choice: ')
    if user_choice == '1':
        print( 'You ordered pizza.')
    elif user_choice == '2':
        print( 'You ordered pasta.')
    elif user_choice == '3':
        print( 'You ordered salad.')
    elif user_choice == '4':
        print( 'You ordered dessert.')
else:
    print( 'Invalid choice. Please try again.')
# Out:
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# You ordered pizza.
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# Invalid choice. Please try again.
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# You ordered salad.
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# Invalid choice. Please try again.
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# Invalid choice. Please try again.
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# Invalid choice. Please try again.
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# Invalid choice. Please try again.
# 1.  Pizza
# 2.  Pasta
# 3.  Salad
# 4.  Dessert
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 9
#       7 while not quite_program:
#       8     print_menu()
# ----> 9     user_choice = input( 'Enter your choice: ')
#      10     if user_choice == '1':
#      11         print( 'You ordered pizza.')
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ## Dyanamic typing

# %%
def add(x, y):
    return x + y

# %%
# passing integer as an argument
# sum of two integers
m = add(2,5)
print(m)
# Out:
# 7

# %%
# passing string as an argument
# concatenation Of two string
n = add('Anup ' ,'Kelkar')
print(n)
# Out:
# Anup Kelkar

# %% [markdown]
# ## Reasons for function

# %%
feet_per_step = 3
steps_per_minute = 70.0
calories_per_minute_walking = 3.5

steps = int(input('Enter number of steps walked: '))

feet = steps * feet_per_step
print('Feet:', feet)
# Out:
# Feet: 120

# %%
minutes = steps / steps_per_minute
calories = minutes * calories_per_minute_walking
print('Calories: ', calories)
# Out:
# Calories:  2.0

# %%
pi_val = 3.14
pizza_diameter_1 = 12.0
circle_radius_1 = pizza_diameter_1/2.0
circle_area_1 = pi_val * circle_radius_1 * circle_radius_1

pizza_diameter_2 = 14.0
circle_radius_2 = pizza_diameter_2 / 2.0
circle_area_2 = pi_val * circle_radius_2 * circle_radius_2

total_pizza_area = circle_area_1 + circle_area_2

print('A 12 and 14 inch pizza has', end=' ')
print(f' {total_pizza_area:,.2f} ' , end='')
print( 'square inches combined.')
# Out:
# A 12 and 14 inch pizza has  266.90 square inches combined.

# %% [markdown]
# ## Writing mathematical functins

# %%
CM_PER_INCH = 2.54
INCHES_PER_FOOT = 12

def height_US_to_cm(feet, inches) :
    """Converts_height in feet/ inches to centimeters"""
    total_inches = feet*INCHES_PER_FOOT + inches
    cm = total_inches * CM_PER_INCH
    return cm

i_feet = 6
i_inches = 4
centimeters = height_US_to_cm(i_feet, i_inches)
print('Centimeters:', centimeters)
# Out:
# Centimeters: 193.04

# %%
def compute_square(num_to_square):
    return num_to_square * num_to_square

c2 = compute_square(7) + compute_square(9)
print('7 squared plus 9 squared is', c2)
# Out:
# 7 squared plus 9 squared is 130

# %%
import math

def calc_circular_base_area(radius):
    return math. pi * radius * radius

def calc_cy1inder_volume(baseRadius, height):
    return calc_circular_base_area(baseRadius) * height

def calc_cy1inder_surface_area(baseRadius, height) :
    return (2 * math.pi * baseRadius * height) + (2 * calc_circular_base_area(baseRadius))

radius = float(input('Enter base radius:'))
height = float(input ('Enter height:'))

print('Cylinder volume:' + f'{calc_cy1inder_volume(radius, height):.3f}')
print( 'Cylinder surface area:' + f'{calc_cy1inder_surface_area(radius,height):.3f}')
# Out:
# Cylinder volume:251.327
# Cylinder surface area:226.195

# %% [markdown]
# ## Function stubs

# %%
def steps_to_feet(num_steps) :
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    pass

steps = int(input('Enter number of steps walked: '))

feet = steps_to_feet(steps)
print(' Feet:', feet)
calories = steps_to_calories(steps)
print('Calories: ', calories)
# Out:
#  Feet: 96
# Calories:  None

# %%
def steps_to_feet(num_steps) :
    feet_per_step = 3
    feet = num_steps * feet_per_step
    return feet

def steps_to_calories(num_steps):
    print('FIXME: finish steps_to_calories')
    return -1

steps = int(input('Enter number of steps walked: '))

feet = steps_to_feet(steps)
print(' Feet:', feet)
calories = steps_to_calories(steps)
print('Calories: ', calories)
# Out:
#  Feet: 96
# FIXME: finish steps_to_calories
# Calories:  -1

# %% [markdown]
# ## Functions with the branches/ loops

# %%
def calc_ebay_fee(sell_price):
  """Returns the fees charged by ebay.com given the selling
  price of fixed-price books, movies, music, or video games.
  fee is $0.50 to list plus 13% of selling price up to $50 .00,
  5% of amount from $50.01 to $1000.00, and
  2% for amount $1000.01 or more."""

  p50 =  0.13 # for amount $50 and lower
  p50_to_1000 =0.05 # for $50.01-$1000
  p1000 = 0.02  # for $ 1000.01 and h igher
  fee = 0.50 # fee to List item

  if sell_price <= 50:
    fee =fee + (sell_price*p50)
  elif sell_price <= 1000:
    fee = fee + (50*p50) + ((sell_price-50)*p50_to_1000)
  else:
    fee = fee + (50*p50) + ((1000-50)*p50_to_1000)\
            + ((sell_price-1000)*p1000)
    return fee

selling_price = float(input('Enter item selling price (ex: 65.00):'))
print('eBay fee: $', calc_ebay_fee(selling_price))
# Out:
# eBay fee: $ None

# %% [markdown]
# ## Functions as objects

# %%
def print_human_head():
    print('||||')
    print('oo')
    print('>')
    print('----')
    return

def print_monkey_head():
    print('  w  w')
    print(' (o)(o)')
    print('  (__)')
    return

def print_figure(face):
    face()
    print('  |')
    print('--|--')
    print('/ | \\')
    print('  |')
    return

# %%
choice = int(input('Enter "1" to draw monkey, "2" for human:'))

if choice ==1:
    print_figure(print_monkey_head)
elif choice == 2:
    print_figure(print_human_head)
# Out:
#   w  w
#  (o)(o)
#   (__)
#   |
# --|--
# / | \
#   |

# %% [markdown]
# ## Scope of variables

# %%
centimeters_per_inch =  2.54
inches_per_foot = 12

def height_US_to_centimeters(feet, inches):
    """ Converts a height in feet/ inches to centimeters."""
    total_inches = (feet * inches_per_foot) + inches # Total inches
    centimeters = total_inches * centimeters_per_inch
    return centimeters

i_feet = int(input('Enter feet: '))
i_inches = int(input( ' Enter inches:'))

print( 'Centimeters: ' , height_US_to_centimeters(i_feet,i_inches))
# Out:
# Centimeters:  939.8000000000001

# %%
employee_name = 'N/A'
def get_name():

    name = input( ' Enter employee name: ' )
    global employee_name
    employee_name = name
get_name ( )
print( ' Employee name: ' , employee_name)
# Out:
#  Employee name:  xyz

# %%
employee_name = 'N/A'
def get_name():
    name = input('Enter employee name: ')
    employee_name = name
get_name()
print('Employee name: ', employee_name)
# Out:
# Employee name:  N/A

# %%
employee_name = 'N/A'
get_name1()
print('Employee name:', employee_name)
def get_name1():
    global employee_name
    name = input('Enter employee name:')
    employee_name = name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 employee_name = 'N/A'
# ----> 2 get_name1()
#       3 print('Employee name:', employee_name)
#       4 def get_name1():
#
# NameError: name 'get_name1' is not defined

# %% [markdown]
# ## Namespaces and scope resolution

# %%
daily_cals = 230 # Daily calories
soda_cals = 200

def drink_soda(cals_left):
    return cals_left - soda_cals
daily_cals = drink_soda(daily_cals)
print(daily_cals)
# Out:
# 30

# %%
def avg(a, b):
    tmp = (a+b)/2.0
    return tmp
a = 5
b = 10
tmp = a
# Creates tmp in Local namespace
+ b # Creates tmp in global namespace
print(f'Avg: {avg(a, b): f}' )
print(f' Sum: {tmp:f}')
# Out:
# Avg:  7.500000
#  Sum: 5.000000

# %% [markdown]
# ## Function argument

# %%
def birthday(age):
    '''Celebrate birthday'''
    age = age + 1
    return age

timmy_age = 7
print(birthday(timmy_age))
# Out:
# 8

# %% [markdown]
# ## keyword default

# %%
def print_book_description (title, author, publisher, year, version, num_chapters, num_pages):
    print('Title:',title)
    print('Author', author)
    print('Publisher', publisher)
    print('Year', year)
    print('Version', version)
    print(f'Number of chapters: {num_chapters}')
    print(f'Number of pages: {num_pages}')

# %%
print_book_description('The Lord of Rings', 'J. R. R. Tolkien', 'George Allen & Unwin', 1954, 1.0, 22, 456)
# Out:
# Title: The Lord of Rings
# Author J. R. R. Tolkien
# Publisher George Allen & Unwin
# Year 1954
# Version 1.0
# Number of chapters: 22
# Number of pages: 456

# %%
print_book_description (title='The Lord of Rings', publisher='George Allen & Unwin', year=1954, author='J. R. R. Tolkien',
version=1.0, num_chapters=22, num_pages=456)
# Out:
# Title: The Lord of Rings
# Author J. R. R. Tolkien
# Publisher George Allen & Unwin
# Year 1954
# Version 1.0
# Number of chapters: 22
# Number of pages: 456

# %%
def print_date(day, month, year, style=0) :
  if style == 0: # American
    print(month, ' / ',day,'/',year)
  elif(style == 1): # European
      print(day, '/' ,month, '/' , year)
  else:
    print( 'Invalid Code')

# %%
print_date(30,7,2012,0)
print_date(30,7, 2012, 1)
print_date(30,7,2012)
# Out:
# 7  /  30 / 2012
# 30 / 7 / 2012
# 7  /  30 / 2012

# %%
def split_check(amount, num_people, tax_percentage, tip_percentage):
    total_bill = amount * (1 + tax_percentage) * (1 + tip_percentage)
    # Split the total bill among the number of people
    per_person = total_bill / num_people
    return per_person
split_check(125.00, 2, 0.095, tip_percentage=0.15)
# Out:
# 78.703125

# %%
def append_to_list(value, my_list=[]):
    my_list.append(value)
    return my_list

numbers = append_to_list(50)     # default List appended with 50
print(numbers)
numbers = append_to_list(100)    # default List appended with 100
print(numbers)
# Out:
# [50]
# [50, 100]

# %%
def append_to_list(value, my_list=None):
    if my_list == None:
        my_list = []
    my_list.append(value)
    return my_list

numbers = append_to_list(50)
print(numbers)
# Out:
# [50]

# %% [markdown]
# ## Arbitory arrgument

# %%
def print_sandwich (bread, slice, *args):
    print(f'Arbitary arguments are ' , end='')
    print(f' {slice} on {bread}' , end='')
    if len(args) > 0:
       print( 'with', end='')
    for extra in args:
        print(extra, end='')
print('')
print_sandwich('wheat', 'turkey', 'mayo')
# Out:
# Arbitary arguments are  turkey on wheatwithmayo

# %%
def print_sandwich (bread, slice, **kwargs): print('The keyword Arguments are:', kwargs)
    print(f'{slice} on {bread}')
    for category, extra in kwargs.items():
    print(f' {category}: {extra}')
    print()
print_sandwich('sourdough', 'kabab', sauce='mayo')
# Out:
#   Cell In[21], line 2
#     print(f'{slice} on {bread}')
#     ^
# IndentationError: unexpected indent

# %%
student_scores = [75, 84, 66, 99, 51, 65]

def get_grade_stats(scores):
    # calculate the arithmetic mean
mean = sum(scores)/len(scores)

# Calculate the standard deviation
tmp = 0
for score in scores:
    tmp += (tmp/len(scores))**2
std_dev = (tmp/1en(scores))**ø.5

# Package and return average, standard deviation in a tuple
return mean, std dev

# Unpack tuple
average, standard_deviation = get_grade_stats(student_scores)

print( 'Average score: ' , average)
print( 'Standard deviation: ' , standard_deviation)
