# %% [markdown]
# ## Lists basics

# %%
my_list = [ 'hello', -4.2, 5]
print( 'my_list[0] -->',my_list[0])
print( ' my_list[1] -->',my_list[1])
print( ' my_list[2]-->',my_list[2])
# Out:
# my_list[0] --> hello
#  my_list[1] --> -4.2
#  my_list[2]--> 5

# %%
my_teams = ['Raptors ' ,'Heat,' 'Nets']
your_teams = my_teams   # create a shared reference to same list

my_teams[1] = 'Lakers' # Modify list element

print('My teams are:', my_teams)  # Both variables have changed
print('Your teams are:', your_teams)    # Both variables have changed
# Out:
# My teams are: ['Raptors ', 'Lakers']
# Your teams are: ['Raptors ', 'Lakers']

# %%
my_teams= ['Raptors', 'Heat', 'Nets']
your_teams = my_teams[:]  # Assign your_teams with a COPY of my_teams

my_teams[1] = 'Lakers'    # Modify list element

print('my teams are:', my_teams)   # List element has changed
# Out:
# my teams are: ['Raptors', 'Lakers', 'Nets']

# %%
colors = ['red','green', 'blue']

colors[1] = 'yellow'   #change list element
print (colors)
# Out:
# ['red', 'yellow', 'blue']

# %%
fav_color = colors [2] # Bind to 'blue'
fav_color= 'turquoise' # List not altered
print(colors)
# Out:
# ['red', 'yellow', 'blue']

# %% [markdown]
# ## List methods

# %%
vals = [1, 4, 16]
print( 'original list: ' ,vals)
# Out:
# original list:  [1, 4, 16]

# %%
appended_value = vals.append(25)
print(appended_value)
# Out:
# None

# %%
vals.insert(2, 18)
print( 'element 18 is inserted at 2 index, list are' ,vals)
# Out:
# element 18 is inserted at 2 index, list are [1, 4, 18, 16, 25]

# %%
value = vals.pop()
print(value)
# Out:
# 25

# %%
removed_value = vals.remove(4)
print(value)
# Out:
# 25

# %%
removed_value = vals.remove(16)
print(removed_value)
# Out:
# None

# %%
val.remove(100)
print(removed_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 val.remove(100)
#       2 print(removed_value)
#
# NameError: name 'val' is not defined

# %% [markdown]
# ## Iterating over a list

# %%
my_list = ['Apple' , 'Mango' , 'Orange']
for my_var in my_list:
    # Loop body statements goes here
    print(my_var)
# Out:
# Apple
# Mango
# Orange

# %%
token = [1, 2, 3, 4, 5]
# Convert strings to integers
nums = []
for token in token:
    nums.append(int(token))
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Print each position and number
for index in range(len(nums)):
    value = nums[index]

    print(f'{index}: {value}' )
# Out:
# 0: 1
# 1: 2
# 2: 3
# 3: 4
# 4: 5

# %%
# Determine maximum even
max_num = None
for num in nums:
     if (max_num  == None) and (num % 2 == 0):
     # First even number found
      max_num = num
     elif (max_num != None) and (num > max_num ) and (num %2 == 0 ):
       # Larger even number found
          max_num = num
print( 'Max even #:', max_num)
# Out:
# Max even #: 4

# %%
nums = [1, 4, 15, 456]

max_even = None
for num in nums:
     if num % 2 == 0:  # The number is even?
        if max_even == None or num > max_even:  # Greatest even number see
           max_even = num
print('max_even:',max_even)
# Out:
# max_even: 456

# %%
# Print each position and number
print()
for pos, val in enumerate(nums):
    print(f'{pos}: {val}' )
# Out:
# 0: 1
# 1: 4
# 2: 15
# 3: 456

# %% [markdown]
# ## List nesting

# %%
my_list = [[10,20], [30,40]]
print( 'First nested list: ',my_list[0])
# Out:
# First nested list:  [10, 20]

# %%
tic_tac_toe = [
    ['x', 'o', 'x'],
    ['', 'x', ''],
    ['o', 'o', 'x'],
]

print(tic_tac_toe[0][0], tic_tac_toe[0][1], tic_tac_toe[0][2])
print(tic_tac_toe[1][0], tic_tac_toe[1][1], tic_tac_toe[1][2])
print(tic_tac_toe[2][0], tic_tac_toe[2][1], tic_tac_toe[2][2])
# Out:
# x o x
#  x
# o o x

# %%
my_list = [
    [10, 20, 55],
    [30, 4, 16]
]
print('Original two dimensional list:', my_list)

# Write to some element
my_list[0][0] = 33
my_list[1][1] = 77
my_list[1][2] = 99

print('Updated two dimensional list',my_list)
# Out:
# Original two dimensional list: [[10, 20, 55], [30, 4, 16]]
# Updated two dimensional list [[33, 20, 55], [30, 77, 99]]

# %%
currency = [
[1.00, 5.00, 10.0], # US Dollars
]
[0.75, 3.77, 7.53], # Euros
[0.65, 3.25, 6.50] # British pounds
for row in currency:
    print('row: ',row)
for cell in row:
    print(cell, end=' ')
print()
# Out:
# row:  [1.0, 5.0, 10.0]
# 1.0 5.0 10.0

# %%
for row_index, row in enumerate (currency):
    for column_index, item in enumerate (row):
        print(f'currency [{row_index}][{column_index}] is {item:.2f}')
# Out:
# currency [0][0] is 1.00
# currency [0][1] is 5.00
# currency [0][2] is 10.00

# %% [markdown]
# ## List slicing

# %%
boston_bruins = ['Ram', 'Shyam', 'Krishna', 'Laxman', 'Bharat', 'Shatrughna']
print(boston_bruins)
print('Elements 0 and 1:', boston_bruins [0:2])
print('Elements 1 and 2:', boston_bruins [1:3])
# Out:
# ['Ram', 'Shyam', 'Krishna', 'Laxman', 'Bharat', 'Shatrughna']
# Elements 0 and 1: ['Ram', 'Shyam']
# Elements 1 and 2: ['Shyam', 'Krishna']

# %%
election_years = [1992, 1996, 2000, 2004, 2008]
print(election_years [0:-1]) # Every year except the last
print(election_years [0:-3]) # Every year except the last three
print(election_years [-3:-1]) # The third and second to Last years
# Out:
# [1992, 1996, 2000, 2004]
# [1992, 1996]
# [2000, 2004]

# %% [markdown]
# ## Loops modifying lists

# %%
my_list = [3.2, 5.0, 16.5, 12.25]

for i in range(len(my_list)):
    my_list [i]+=5
print(my_list)
# Out:
# [8.2, 10.0, 21.5, 17.25]

# %%
# change negative values to 0
for num in nums:
     if num < 0:
       num = 0 # Logic error: "temp" variable "num" set to 0

# Print new numbers
print("New numbers:" , end='')
for num in nums:
    print(num, end='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # change negative values to 0
# ----> 2 for num in nums:
#       3      if num < 0:
#       4        num = 0 # Logic error: "temp" variable "num" set to 0
#
# NameError: name 'nums' is not defined

# %%
# Convert strings to integers
nums = []
for token in tokens:
nums. append( int(token) )
print (nums)
# Out:
#   Cell In[13], line 4
#     nums. append( int(token) )
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %%
nums1 = (5, 10, 15)
nums2 = [10,15]

print(f'nums1: {nums1}')
for pos, val in enumerate(nums1):
    print(f' {pos}: {val}')

print ( )
print(f'nums2: {nums2}')
for pos, val in enumerate(nums2):
    print(f' {pos}: {val}' )
# Out:
# nums1: (5, 10, 15)
#  0: 5
#  1: 10
#  2: 15
#
# nums2: [10, 15]
#  0: 10
#  1: 15

# %% [markdown]
# ## List comprehension

# %%
my_list = [ 10, 20, 30]
list_plus_5 = [(i+5) for i in my_list]
print('New list contains:', list_plus_5)
# Out:
# New list contains: [15, 25, 35]

# %%
# Get a list of integers from the user
numbers = [int(i) for i in input('Enter numbers:').split()]

# Return a list of only even numbers
even_numbers = [i for i in numbers if (i % 2)==0]
print('Even numbers only:', even_numbers)
# Out:
# Even numbers only: [56]

# %%
#Get a list of integers from the user
numbers = [int(i) for i in input('Enter numbers:').split()]
# Return a list of only even numbers
even_numbers = [i for i in numbers if (i % 2) == 0] 
print('Even numbers only:', even_numbers)
# Out:
# Even numbers only: [48]

# %%
numbers=[int(i) for i in input(' Enter numbers:').split()]
sorted_numbers = sorted(numbers)
print('\nOriginal numbers:',numbers)
# Out:
# Original numbers: [56]

# %%
my_list = [[25],[15, 25, 35], [10,15]]

sorted_list = sorted(my_list,key=max)

print('Sorted list:', sorted_list)
# Out:
# Sorted list: [[10, 15], [25], [15, 25, 35]]

# %%
numbers = [int(i) for i in input('Enter numbers: ').split()]
sorted_numbers = sorted (numbers)
print('\nOriginal numbers:', numbers)
print('Sorted numbers:', sorted_numbers)
Sorted_numbers: [-100, 4, 5, 5, 5, 23]
# Out:
# Original numbers: [100]
# Sorted numbers: [100]

# %%
my_list = [[25], [15, 25, 35], [10, 15]]
sorted_list = sorted(my_list, key=max)
print('Sorted list:', sorted_list)
# Out:
# Sorted list: [[10, 15], [25], [15, 25, 35]]

# %% [markdown]
# ## Dictionary

# %%
# Creating a dictionary
my_diet = {'apple': 5, 'banana': 3, 'orange': 7}

# Printing the dictionary
print(my_diet)
# Out:
# {'apple': 5, 'banana': 3, 'orange': 7}

# %%
if 'apple' in my_diet:
    print("Key exists in the dictionary.")
else:
     print("Key does not exist in the dictionary.")
# Out:
# Key exists in the dictionary.

# %% [markdown]
# ## Dictionary methods

# %%
my_diet.get('apple')
# Out:
# 5

# %%
my_diet.update({'banana': 4, 'grapes': 10})

# %% [markdown]
# ## Nested dictionory

# %%
# Nested dictionaries with students information
students = {
    "Alice": {"age": 20, "grade": 85},
    "Bob": {"age": 22, "grade": 90},
    "Charlie": {"age": 21, "grade": 78}
}

# %%
# Print the age and grade of each student
for student, info in students.items():
    age = info['age']
    grade = info['grade']
    print(f'{student}: Age={age}, Grade={grade}')
# Out:
# Alice: Age=20, Grade=85
# Bob: Age=22, Grade=90
# Charlie: Age=21, Grade=78

# %% [markdown]
# ## Iterating over Dictionory

# %%
num_calories = dict(Coke=90, Coke_zero=0, Pepsi=94)
for soda, calories in num_calories . items():
    print(f'{soda}:{calories}')
for soda in num_calories.keys():
    print(soda)
for soda in num_calories.values():
    print(soda)
# Out:
# Coke:90
# Coke_zero:0
# Pepsi:94
# Coke
# Coke_zero
# Pepsi
# 90
# 0
# 94
