# %% [markdown]
# **1. Checker for integer string**

# %% [markdown]
# Forms often allow a user to enter an integer. Write a program that takes in a string representing an integer as input, and outputs yes if every character is a digit 0-9.
#
# Ex: If the input is:
#
# 1995
# the output is:
#
# yes
# Ex: If the input is:
#
# 42,000
# or any string with a non-integer character, the output is:
#
# no
#
# Paste the following line of code in editor.

# %%
user_string = int(input())
print(str(user_string).isdigit())
# Out:
# True

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
1995
Standard output exactly matches
yes

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
42,000
Standard output exactly matches
no

# %% [markdown]
# **Hint 3**

# %%
Compare output (2 points)
When input is
1995!
Standard output exactly matches
no
Compare output (2 points)
When input is
93875
Standard output exactly matches
yes
Compare output (2 points)
When input is
32.45
Standard output exactly matches
no

# %% [markdown]
# **2. Name format**

# %% [markdown]
# Many documents use a specific format for a person's name. Write a program whose input is:
#
# firstName middleName lastName
#
# and whose output is:
#
# lastName, firstInitial.middleInitial.
#
# Ex: If the input is:
#
# Pat Silly Doe
# the output is:
#
# Doe, P.S.
# If the input has the form:
#
# firstName lastName
#
# the output is:
#
# lastName, firstInitial.
#
# Ex: If the input is:
#
# Julia Clark
# the output is:
#
# Clark, J.
#
# Paste the following line of code in editor.

# %%
first_name = input()
middle_name = input()
last_name = input()
if first_name and middle_name and last_name:
    print(f'{last_name} {first_name[0]}.{middle_name[0]}.')
elif first_name and last_name:
    print(f'{last_name} {first_name[0]}.')
# Out:
# Clark J.

# %% [markdown]
# **Hint 1**

# %%
Compare output (3 points)
When input is
Pat Silly Doe
Standard output exactly matches
Doe, P.S.

# %% [markdown]
# **Hint 2**

# %%
ompare output (2 points)
When input is
Julia Clark
Standard output exactly matches
Clark, J.

# %% [markdown]
# **Hint 3**

# %%
Compare output (3 points)
When input is
Daniel Tomas Windham
Standard output exactly matches
Windham, D.T.

Compare output (2 points)
When input is
Michael Jordan
Standard output exactly matches
Jordan, M.

# %% [markdown]
# **3. Count characters**

# %% [markdown]
# Write a program whose input is a string which contains a character and a phrase, and whose output indicates the number of times the character appears in the phrase. The output should include the input character and use the plural form, n's, if the number of times the characters appears is not exactly 1.
#
# Ex: If the input is:
# n Monday
#
# the output is:
# 1 n
#
# Ex: If the input is:
# z Today is Monday
#
# the output is:
# 0 z's
#
# Ex: If the input is:
# n It's a sunny day
#
# the output is:
# 2 n's
# Case matters. n is different than N.
#
# Ex: If the input is:
# n Nobody
#
# the output is:
# 0 n's
#
# Paste the following code in editor.

# %%
my_string = str(input())
print(my_string.count('n'))
# Out:
# 0

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
n Monday
Standard output exactly matches
1 n

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
z Today is Monday
Standard output exactly matches
0 z's

# %% [markdown]
# **Hint 3**

# %%
Compare output (2 points)
When input is
n It's a sunny day
Standard output exactly matches
2 n's

Compare output (2 points)
When input is
t this is a sentence with many t's
Standard output exactly matches
4 t's

Compare output (2 points)
When input is
x X
Standard output exactly matches
0 x's

# %% [markdown]
# **4. Mad Lib - loops**

# %% [markdown]
# Mad Libs are activities that have a person provide various words, which are then used to complete a short story in unexpected (and hopefully funny) ways.
#
# Write a program that takes a string and an integer as input, and outputs a sentence using the input values as shown in the example below. The program repeats until the input string is quit and disregards the integer input that follows.
#
# Ex: If the input is:
#
# apples 5
# shoes 2
# quit 0
# the output is:
#
# Eating 5 apples a day keeps the doctor away.
# Eating 2 shoes a day keeps the doctor away.
#
# Write code in editor.

# %% [markdown]
# **Hint 1**

# %%
Compare output (5 points)
When input is
apples 5
shoes 2
quit 0

Standard output exactly matches

Eating 5 apples a day keeps the doctor away.
Eating 2 shoes a day keeps the doctor away.

# %% [markdown]
# **Hint 2**

# %%
Compare output (5 points)
When input is
cars 99
quit 0
Standard output exactly matches
Eating 99 cars a day keeps the doctor away.

# %% [markdown]
# **5. Palindrome**

# %% [markdown]
# A palindrome is a word or a phrase that is the same when read both forward and backward. Examples are: "bob," "sees," or "never odd or even" (ignoring spaces). Write a program whose input is a word or phrase, and that outputs whether the input is a palindrome.
#
# Ex: If the input is:
# bob
#
# the output is:
# bob is a palindrome
#
# Ex: If the input is:
# bobby
#
# the output is:
# bobby is not a palindrome
#
# Hint: Start by removing spaces. Then check if a string is equivalent to its reverse.
#
# Write code in editor.

# %%
phrase = input()
if phrase == phrase[::-1]:
    print(f'{phrase} is a palindrome')
else:
    print(f'{phrase} is not a palindrome')
# Out:
# bobby is not a palindrome

# %% [markdown]
# **Hint 1**

# %%
Compare output (1 point)
When input is
bob
Standard output exactly matches
bob is a palindrome

# %% [markdown]
# **Hint 2**

# %%
Compare output (1 point)
When input is
sees
Standard output exactly matches
sees is a palindrome

# %% [markdown]
# **Hint 3**

# %%
Compare output (1 point)
When input is
never odd or even
Standard output exactly matches
never odd or even is a palindrome

Compare output (1 point)
When input is
statistics
Standard output exactly matches
statistics is not a palindrome

Compare output (2 points)
When input is
dr awkward
Standard output exactly matches
dr awkward is a palindrome

Compare output (2 points)
When input is
evil is alive
Standard output exactly matches
evil is alive is not a palindrome

Compare output (1 point)
When input is
no lemon no melon
Standard output exactly matches
no lemon no melon is a palindrome

Compare output (1 point)
When input is
seem
Standard output exactly matches
seem is not a palindrome

# %% [markdown]
# **6. Acronyms**

# %% [markdown]
# An acronym is a word formed from the initial letters of words in a set phrase. Write a program whose input is a phrase and whose output is an acronym of the input. Append a period (.) after each letter in the acronym. If a word begins with a lower case letter, don't include that letter in the acronym. Assume the input has at least one upper case letter.
#
# Ex: If the input is:
#
# Institute of Electrical and Electronics Engineers
#
# the output is:
#
# I.E.E.E.
#
# Hint: Use isupper() to check if a letter is upper case.
#
# Write code in editor and pass all the test cases given below in Hint tab.

# %% [markdown]
# **Hint 1**

# %%
Compare output (3 points)
When input is
Institute of Electrical and Electronics Engineers
Standard output exactly matches
I.E.E.E.

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
As Soon As Possible
Standard output exactly matches
A.S.A.P.

# %% [markdown]
# **Hint 3**

# %%
Compare output (3 points)
When input is
University of California San Diego
Standard output exactly matches
U.C.S.D.

Compare output (2 points)
When input is
Self Contained Underwater Breathing Apparatus
Standard output exactly matches
S.C.U.B.A.

# %% [markdown]
# **7. Contains the character**

# %% [markdown]
# Write a program that reads a character, then reads in a list of words. The output of the program is every word in the list that contains the character at least once. Assume at least one word in the list will contain the given character.
#
# Ex: If the input is:
# z
# hello zoo sleep drizzle
#
# the output is:
#
# zoo
# drizzle
#
# Keep in mind that the character 'a' is not equal to the character 'A'.
#
# Write code in editor and it is mandatory to pass all test cases are given in Hint tabs are as follows.

# %% [markdown]
# **Hint 1**

# %%
Compare output (3 points)
When input is
z
hello zoo sleep drizzle

Standard output exactly matches
zoo
drizzle

# %% [markdown]
# **Hint 2**

# %%
Compare output (4 points)
When input is
s
school star SOS

Standard output exactly matches
school
star

# %% [markdown]
# **Hint 3**

# %%
Compare output (3 points)
When input is
r
red roses racecar room sunrise rock train

Standard output exactly matches
red
roses
racecar
room
sunrise
rock
train

# %% [markdown]
# **8. Warm up: Parsing strings**

# %% [markdown]
# (1) Prompt the user for a string that contains two strings separated by a comma. (1 pt)
#
# Examples of strings that can be accepted:
# * Jill, Allen
# * Jill , Allen
# * Jill,Allen
# Ex:
#
# Enter input string:
# Jill, Allen
#
# (2) Report an error if the input string does not contain a comma. Continue to prompt until a valid string is entered. Note: If the input contains a comma, then assume that the input also contains two strings. (2 pts)
#
# Ex:
#
# Enter input string:
# Jill Allen
# Error: No comma in string.
#
# Enter input string: Jill, Allen
#
# (3) Using string splitting, extract the two words from the input string and then remove any spaces. Output the two words. (2 pts)
#
# Ex:
#
# Enter input string:
# Jill, Allen
# First word: Jill
# Second word: Allen
#
# (4) Using a loop, extend the program to handle multiple lines of input. Continue until the user enters q to quit. (2 pts)
#
# Ex:
#
# Enter input string:
# Jill, Allen
# First word: Jill
# Second word: Allen
#
# Enter input string:
# Golden , Monkey
# First word: Golden
# Second word: Monkey
#
# Enter input string:
# Washington,DC
# First word: Washington
# Second word: DC
#
# Enter input string:
# q

# %% [markdown]
# **Hint 1**

# %%
Compare output (1 point)
When input is
Jill, Allen
q
Standard output starts with
Enter input string:

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
Jill Allen
JillAllen
Jill Allen
q
Standard output starts with
Enter input string:
Error: No comma in string.

Enter input string:
Error: No comma in string.

Enter input string:
Error: No comma in string.

Enter input string:

# %% [markdown]
# **Hint 3.**

# %%
Compare output (2 points)
When input is
Jill, Allen
q
Standard output starts with
Enter input string:
First word: Jill
Second word: Allen
Compare output (1 point)
When input is
Jill, Allen
Golden , Monkey
Washington,DC
q
Standard output exactly matches
Enter input string:
First word: Jill
Second word: Allen
Enter input string:
First word: Golden
Second word: Monkey

Enter input string:
First word: Washington
Second word: DC

Enter input string:
5. Compare output (1 point)
When input is
Clarke , Geffen
Signals,Systems
Macintosh, Apple
q
Standard output exactly matches
Enter input string:
First word: Clarke
Second word: Geffen

Enter input string:
First word: Signals
Second word: Systems

Enter input string:
First word: Macintosh
Second word: Apple

Enter input string:

# %% [markdown]
# **9. Remove all non-alpha characters**

# %% [markdown]
# Write a program that removes all non-alpha characters from the given input.
#
# Ex: If the input is:
# -Hello, 1 world$!
#
# the output is:
# Helloworld
#
# run all test cases given in hint tabs.

# %% [markdown]
# **Hint 1**

# %%
Compare output (3 points)
When input is
-Hello, 1 world$!
Standard output exactly matches
Helloworld

# %% [markdown]
# **Hint 2**

# %%
Compare output (3 points)
When input is
This !$ @ sentence.
Standard output exactly matches
Thissentence

# %% [markdown]
# **Hint 3**

# %%
Compare output (2 points)
When input is
Look! Multiple spaces.
Standard output exactly matches
LookMultiplespaces

Compare output (2 points)
When input is
flying
Standard output exactly matches
flying
