# %% [markdown]
# **1. Remove gray from RGB**

# %% [markdown]
# Summary: Given integer values for red, green, and blue, subtract the gray from each value.
#
# Computers represent color by combining the sub-colors red, green, and blue (rgb). Each sub-color's value can range from 0 to 255. Thus (255, 0, 0) is bright red, (130, 0, 130) is a medium purple, (0, 0, 0) is black, (255, 255, 255) is white, and (40, 40, 40) is a dark gray. (130, 50, 130) is a faded purple, due to the (50, 50, 50) gray part. (In other words, equal amounts of red, green, blue yield gray).
#
# Given values for red, green, and blue, remove the gray part.
#
# Ex: If the input is:
#
# 130
# 50
# 130
# the output is:
#
# 80 0 80
# Find the smallest value, and then subtract it from all three values, thus removing the gray.
#
# Note: There is a link follows converts rgb values into colors.
# https://www.mathsisfun.com/hexadecimal-decimal-colors.html
#
# write code in the editor window.

# %%
red_amount = int(input('Enter the amount of red'))
green_amount = int(input('Enter the amount of green'))
blue_amount = int(input('Enter the amount of blue'))
min_value = red_amount - blue_amount - green_amount//3
if red_amount < min_value:
    min_value = red_amount
if green_amount < min_value:
    min_value = green_amount
if blue_amount < min_value:
    min_value = blue_amount
red_amount = red_amount - min_value
green_amount = green_amount - min_value
blue_amount = blue_amount - min_value
print(red_amount, green_amount, blue_amount)
# Out:
# 146 66 146

# %% [markdown]
# **Hint 1**

# %%
# Get rgb color values
red_amount = int(input())
green_amount = int(input())
blue_amount = int(input())

# Find minimum value
min_value = red_amount
if green_amount < min_value:
    min_value = green_amount

elif blue_amount < min_value:
    min_value = blue_amount

Subtract minimum_value from all colors, thus removing any gray
red_amount = red_amount - min_value
green_amount = green_amount - min_value
blue_amount = blue_amount - min_value

Output new color values with gray removed
print(red_amount, green_amount, blue_amount)

# %% [markdown]
# **2. Smallest number**

# %% [markdown]
# Write a program whose inputs are three integers, and whose output is the smallest of the three values.
#
# Ex: If the input is:
#
# 7
# 15
# 3
# the output is:3

# %%
user_num1 = int(input('Enter the value'))
user_num2 = int(input('Enter the value'))
user_num3 = int(input('Enter the value'))
if user_num1 <= user_num2 and user_num2 <= user_num3:
 print(user_num1)
elif user_num2 <= user_num1 and user_num2 <= user_num3:
    print(user_num2)
else:
    print(user_num3)
# Out:
# 3

# %% [markdown]
# **3. Interstate highway numbers**

# %% [markdown]
# Primary U.S. interstate highways are numbered 1-99. Odd numbers (like the 5 or 95) go north/south, and evens (like the 10 or 90) go east/west. Auxiliary highways are numbered 100-999, and service the primary highway indicated by the rightmost two digits. Thus, I-405 services I-5, and I-290 services I-90. Note: 200 is not a valid auxiliary highway because 00 is not a valid primary highway number.
#
# Given a highway number, indicate whether it is a primary or auxiliary highway. If auxiliary, indicate what primary highway it serves. Also indicate if the (primary) highway runs north/south or east/west.
#
# Ex: If the input is:
#
# 90
# the output is:
#
# I-90 is primary, going east/west.
# Ex: If the input is:
#
# 290
# the output is:
#
# I-290 is auxiliary, serving I-90, going east/west.
# Ex: If the input is:
#
# 0
# the output is:
#
# 0 is not a valid interstate highway number.
# Ex: If the input is:
#
# 200
# the output is:
#
# 200 is not a valid interstate highway number.
#
# for more info on highway numbering links are as follows.
# https://en.wikipedia.org/wiki/Interstate_Highway_System#Numbering_system
#
# Paste the following code in editor window

# %%
highway_num = int(input('Enter the highway number'))
if highway_num < 0:
    print('Error: Invalid input')
if highway_num < 100:
    if highway_num % 2 == 0:
        print(f'Interstate {highway_num} is primary, going east/west.')
    else:
        print(f'Interstate {highway_num} is primary, going north/south.')
if highway_num < 1000 and highway_num > 100:
   print('The highway is auxiliary.')
# Out:
# The highway is auxiliary.

# %% [markdown]
# **4. Seasons**

# %% [markdown]
# Write a program that takes a date as input and outputs the date's season in the northern hemisphere. The input is a string to represent the month and an int to represent the day.
#
# Ex: If the input is:
#
# April
# 11
# the output is:
#
# Spring
# In addition, check if the string and int are valid (an actual month and day).
#
# Ex: If the input is:
#
# Blue
# 65
# the output is:
#
# Invalid
# The dates for each season in the northern hemisphere are:
# Spring: March 20 - June 20
# Summer: June 21 - September 21
# Autumn: September 22 - December 20
# Winter: December 21 - March 19
#
# Paste the following code in editor window

# %%
input_month = input('Enter the month')
input_day = int(input('Enter the date'))
if input_month <= 'June' and input_day == 20:
    print('It is Spring in the northen hemisphere')
elif input_month <= 'September' and input_day == 21:
    print('It is Summer in the northen hemisphere')
elif input_month <= 'December' and input_day <= 20:
    print('It is Autumn in the northen hemisphere')
else:
    print('It is Winter in the northern hemisphere')
# Out:
# It is Winter in the northern hemisphere

# %% [markdown]
# **5. Exact change**

# %% [markdown]
# Write a program with total change amount as an integer input, and output the change using the fewest coins, one coin type per line. The coin types are Dollars, Quarters, Dimes, Nickels, and Pennies. Use singular and plural coin names as appropriate, like 1 Penny vs. 2 Pennies.
#
# Ex: If the input is:
#
# 0
# (or less than 0), the output is:
#
# No change
# Ex: If the input is:
#
# 45
# the output is:
#
# 1 Quarter
# 2 Dimes
#
# Paste the following line of code in editor window.

# %%
user_num = int(input('Enter the value'))
input_currency = input('Enter the currency')
if input_currency == 'Dollars' and user_num >= 100:
    dollars = user_num // 100
    cents = user_num % 100
    print('You have one Dollar')
elif input_currency == 'Quarter' and user_num >= 25:
    quarters = user_num // 25
    cents = user_num % 25
    print('You have one Quarter')
elif input_currency == 'Dime' and user_num >= 10:
    dimes = user_num // 10
    cents = user_num % 10
    print('You have one Dime')
elif input_currency == 'Nickel' and user_num >= 5:
    nickels = user_num // 5
    cents = user_num % 5
    print('You have one Nickel')
elif input_currency == 'Penny' and user_num >= 1:
    pennies = user_num // 1
    print('You have one Penny')

# %% [markdown]
# **6. Leap year**

# %% [markdown]
# A year in the modern Gregorian Calendar consists of 365 days. In reality, the earth takes longer to rotate around the sun. To account for the difference in time, every 4 years, a leap year takes place. A leap year is when a year has 366 days: An extra day, February 29th. The requirements for a given year to be a leap year are:
#
# The year must be divisible by 4
#
# If the year is a century year (1700, 1800, etc.), the year must be evenly divisible by 400
#
# Some example leap years are 1600, 1712, and 2016.
#
# Write a program that takes in a year and determines whether that year is a leap year.
#
# Ex: If the input is:
#
# 1712
# the output is:
#
# 1712 - leap year
# Ex: If the input is:
#
# 1913
# the output is:
#
# 1913 - not a leap year
#
# Paste the following code in editor window.

# %%
year = int(input('Enter the year'))
if year % 4 == 0:
    print('It is a leap year')
else:
    print('It is not a leap year')
# Out:
# It is a leap year

# %% [markdown]
# **7. Warm up: Automobile service cost**

# %% [markdown]
# (1) Prompt the user for an automobile service. Output the user's input. (1 pt)
#
# Ex:
#
# Enter desired auto service:
# Oil change
# You entered: Oil change
#
# (2) Output the price of the requested service. (4 pts)
#
# Ex:
#
# Enter desired auto service:
# Oil change
# You entered: Oil change
# Cost of oil change: $35
#
# The program should support the following services (all integers):
#
# Oil change -- $35
#
# Tire rotation -- $19
#
# Car wash -- $7
# If the user enters a service that is not listed above, then output the following error message:
#
# Error: Requested service is not recognized

# %%
user_num = input('Enter the value')
auto_services = ['Oil Change', 'Tire Rotation', 'Car Wash']
if user_num == auto_services[0]:
    print('The cost of Oil Change is $35')
elif user_num == auto_services[1]:
    print('The cost of Tire Rotation is $19')
elif user_num == auto_services[2]:
    print('The cost of Car Wash is $7')
# Out:
# The cost of Oil Change is $35

# %% [markdown]
# **8. Program: Automobile service invoice**

# %% [markdown]
# (1) Output a menu of automotive services and the corresponding cost of each service. (2 pts)
#
# Ex:
#
# Davy's auto shop services
#
# Oil change -- $35
# Tire rotation -- $19
# Car wash -- $7
# Car wax -- $12
# (2) Prompt the user for two services from the menu. (2 pts)
#
# Ex:
#
# Select first service:
# Oil change
#
# Select second service:
# Car wax
#
# (3) Output an invoice for the services selected. Output the cost for each service and the total cost. (3 pts)
#
# Davy's auto shop invoice
# Service 1: Oil change, $35
#
# Service 2: Car wax, $12
#
# Total: $47
#
# (4) Extend the program to allow the user to enter a dash (-), which indicates no service. (3 pts)
#
# Ex:
#
# Davy's auto shop services
#
# Oil change -- $35
# Tire rotation -- $19
# Car wash -- $7
# Car wax -- $12
# Select first service:
# Tire rotation
# Select second service: _
#
# Davy's auto shop invoice
#
# Service 1: Tire rotation, $19
# Service 2: No service
#
# Total: $19

# %%
print('DAVY\'S AUTO SHOP SERVICES')

user_num = input('Enter the service')
print(f'First service: {user_num}')
if user_num == 'Oil Change':
    cost1 = '35'
    print('The cost of Oil Change is $35')
elif user_num == 'Tire Rotation':
    cost1 = '19'
    print('The cost of Tire Rotation is $19')
elif user_num == 'Car Wash':
    cost1 = '7'
    print('The cost of Car Wash is $7')
else:
    print('No service')

user_num2 = input('Enter the service')
print(f'Second service: {user_num2}')
if user_num2 == 'Oil Change':
    cost2 = '35'
    print('The cost of Oil Change is $35')
elif user_num2 == 'Tire Rotation':
    cost2 = '19'
    print('The cost of Tire Rotation is $19')
elif user_num2 == 'Car Wash':
    cost2 = '7'
    print('The cost of Car Wash is $7')
else:
    print('No service')
total_cost = int(cost1) + int(cost2)
print(f'The total cost of both services is ${total_cost}')
# Out:
# DAVY'S AUTO SHOP SERVICES
# First service: Oil Change
# The cost of Oil Change is $35
# Second service: Car Wash
# The cost of Car Wash is $7
# The total cost of both services is $42

# %% [markdown]
# **9. Golf scores**

# %% [markdown]
# Golf scores record the number of strokes used to get the ball in the hole. The expected number of strokes varies from hole to hole and is called par (i.e. 3, 4, or 5). Each score's name is based on the actual strokes taken compared to par:
#
# "Eagle": number of strokes is two less than par
# "Birdie": number of strokes is one less than par
# "Par": number of strokes equals par
# "Bogey": number of strokes is one more than par
# Given two integers that represent par and the number of strokes used, write a program that prints the appropriate score name. Print "Error" if par is not 3, 4, or 5.
# Ex: If the input is:
#
# 4
# 3
# the output is:
#
# Birdie
