# %% [markdown]
# **1. Divide by x**

# %% [markdown]
# Write a program using integers user_num and x as input, and output user_num divided by x three times.
#
# Ex: If the input is:
#
# 2000
# 2
# Then the output is:
#
# 1000 500 250
# Note: In Python 3, integer division discards fractions. Ex: 6 // 4 is 1 (the 0.5 is discarded).
#
# run code by passing every test cases.

# %%
user_num = int(input('Enter the integer: \n'))
x = int(input('Enter the integer:\n'))
user_num//x
user_num2 = user_num//x
print(user_num2)
user_num3 = user_num2//x
print(user_num3)
user_num4 = user_num3//x
print(user_num4)
# Out:
# 1000
# 500
# 250

# %% [markdown]
# **Hint 1**

# %%
Compare output (4 points)
When input is
2000
2
Standard output exactly matches
1000 500 250

# %% [markdown]
# **Hint 2**

# %%
Compare output (3 points)
When input is
100
4
Standard output exactly matches
25 6 1

# %% [markdown]
# **Hint 3**

# %%
Compare output (3 points)
When input is
8000
-2
Standard output exactly matches
-4000 2000 -1000

# %% [markdown]
# **2. Driving costs**

# %% [markdown]
# Driving is expensive. Write a program with a car's miles/gallon and gas dollars/gallon (both floats) as input, and output the gas cost for 20 miles, 75 miles, and 500 miles.
#
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'{your_value1:.2f} {your_value2:.2f} {your_value3:.2f}')
#
# Ex: If the input is:
#
# 20.0
# 3.1599
# Then the output is:
#
# 3.16 11.85 79.00
# Note: Real per-mile cost would also include maintenance and depreciation.

# %%
car_mile = float(input('Enter the distance'))
gallon = float(input('Enter the value'))
car_mile//gallon
print(car_mile//gallon)
print(f'{car_mile//gallon}')
# Out:
# 6.0
# 6.0

# %% [markdown]
# **Hint 1**

# %%
Compare output (5 points)
When input is
20.0
3.1599
Standard output exactly matches
3.16 11.85 79.00

# %% [markdown]
# **Hint 2**

# %%
Compare output (5 points)
When input is
20.0
3.1599
Standard output exactly matches
3.16 11.85 79.00

# %% [markdown]
# **3. Types:Input and formatted output: Caffeine levels**

# %% [markdown]
# A half-life is the amount of time it takes for a substance or entity to fall to half its original value. Caffeine has a half-life of about 6 hours in humans. Given caffeine amount (in mg) as input, output the caffeine level after 6, 12, and 24 hours. Use a string formatting expression with conversion specifiers to output the caffeine amount as floating-point numbers.
#
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'{your_value:.2f}')
# Ex: If the input is:
#
# 100
#
# the output is:
#
# After 6 hours: 50.00 mg
# After 12 hours: 25.00 mg
# After 24 hours: 6.25 mg
# Note: A cup of coffee has about 100 mg. A soda has about 40 mg. An "energy" drink (a misnomer) has between 100 mg and 200 mg.
#
# Paste the following code in editor window

# %%
caffeine_mg = float(input())
time = float(input('Enter the time in hours: '))
caffeine_mg//time
print(f'expected caffeine mg: {caffeine_mg//time}')
# Out:
# expected caffeine mg: 0.0

# %% [markdown]
# **4.Expression for calories burned during workout**

# %% [markdown]
# The following equation estimates the average calories burned for a person when exercising, which is based on a scientific journal article (source):https://www.tandfonline.com/doi/abs/10.1080/02640410470001730089
#
# Calories = ( (Age x 0.2757) + (Weight x 0.03295) + (Heart Rate x 1.0781) — 75.4991 ) x Time / 8.368
#
# Write a program using inputs age (years), weight (pounds), heart rate (beats per minute), and time (minutes), respectively. Output the average calories burned for a person.
#
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'Calories: {calories:.2f} calories')
#
# Ex: If the input is:
#
# 49
# 155
# 148
# 60
# then the output is:
#
# Calories: 736.21 calories

# %%
user_age = int(input('Enter your age: '))
user_weight = int(input('Enter your weight in pounds: '))
heart_rate = int(input('Enter your heart rate: '))
time_minutes = int(input('Enter the time in minutes: '))
Calories = ((user_age * 0.2757) + (user_weight * 0.03295) + (heart_rate * 1.0781) -75.4991)  * time_minutes / 8.368
print(f'Calories burned: {Calories:.2f}')
# Out:
# Calories burned: 736.21

# %% [markdown]
# **Hint 1**

# %%
Compare output (5 points)
When input is
49
155
148
60
Standard output exactly matches
Calories: 736.21 calories

# %% [markdown]
# **Hint** 2

# %%
Compare output (5 points)
When input is
25
130
120
45
Standard output exactly matches
Calories: 349.81 calories

# %% [markdown]
# **5. Using math functions**

# %% [markdown]
# Given three floating-point numbers x, y, and z, output x to the power of z, x to the power of (y to the power of z), the absolute value of (x minus y), and the square root of (x to the power of z).
#
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'{your_value1:.2f} {your_value2:.2f} {your_value3:.2f} {your_value4:.2f}')
#
# Ex: If the input is:
#
# 5.0
# 1.5
# 3.2
# Then the output is:
#
# 172.47 361.66 3.50 13.13
#
# import math
# ''' Type your code here. '''

# %%
x = float(input())
y = float(input())
z = float(input())
num_values = x ** z
print(f'{num_values:.2f}')
num_value2 = x ** (y**z)
print(f'{num_value2:.2f}')
num_value3 = x - y
print(f'{num_value3:.2f}')
num_value4 = (x ** z) ** 0.5
print(f'{num_value4:.2f}')
# Out:
# 172.47
# 361.66
# 3.50
# 13.13

# %% [markdown]
# **Hint 1**

# %%
Compare output (5 points)
When input is
5.0
1.5
3.2
Standard output exactly matches
172.47 361.66 3.50 13.13

# %% [markdown]
# **Hint 2**

# %%
Compare output (5 points)
When input is
3.7
-3
5
Standard output exactly matches
693.44 0.00 6.70 26.33

# %% [markdown]
# **6. Musical note frequencies**

# %% [markdown]
# On a piano, a key has a frequency, say f0. Each higher key (black or white) has a frequency of f0 * rn, where n is the distance (number of keys) from that key, and r is 2(1/12). Given an initial key frequency, output that frequency and the next 3 higher key frequencies.
#
# Output each floating-point value with two digits after the decimal point, then the units ("Hz"), then a newline, using the following statement:
# print(f'{your_value:.2f} Hz')
#
# Ex: If the input is:
#
# 440
# (which is the A key near the middle of a piano keyboard), the output is:
#
# 440.00 Hz
# 466.16 Hz
# 493.88 Hz
# 523.25 Hz
# Note: To compute the next 3 higher key frequencies, use one statement to compute r = 2(1/12) using the pow function (remember to import the math module). Then use that r in subsequent statements that use the formula fn = f0 * rn with n being 1, 2, and finally 3.

# %%
fo = int(input('Enter the frequency of a key: '))
r = 2 ** (1/12)
n = '0,1,2,3'
frequency = fo * (r ** 0)
frequency1 = fo * (r ** 1)
frequency2 = fo * (r ** 2)
frequency3 = fo * (r ** 3)
print(f'{frequency:.2f} Hz')
print(f'{frequency1:.2f} Hz')
print(f'{frequency2:.2f} Hz')
print(f'{frequency3:.2f} Hz')
# Out:
# 220.00 Hz
# 233.08 Hz
# 246.94 Hz
# 261.63 Hz

# %% [markdown]
# **Hint 1**

# %%
A above middle C (5 points)
When input is
440
Standard output exactly matches
440.00 Hz
466.16 Hz
493.88 Hz
523.25 Hz

# %% [markdown]
# **Hint 2**

# %%
A below middle C (5 points)
When input is
220
Standard output exactly matches
220.00 Hz
233.08 Hz
246.94 Hz
261.63 Hz

# %% [markdown]
# **7. Warm up: Variables, input, and type conversion**

# %% [markdown]
# (1) Prompt the user to input an integer between 32 and 126, a float, a character, and a string, storing each into separate variables. Then, output those four values on a single line separated by a space. (Submit for 2 points).
#
# Enter integer (32 - 126):
# 99
# Enter float:
# 3.77
# Enter character:
# z
# Enter string:
# Howdy
# 99 3.77 z Howdy
#
# (2) Extend to also output in reverse. (Submit for 1 point, so 3 points total).
#
# Enter integer (32 - 126):
# 99
# Enter float:
# 3.77
# Enter character:
# z
# Enter string:
# Howdy
# 99 3.77 z Howdy
# Howdy z 3.77 99
#
# (3) Extend to convert the integer to a character by using the 'chr()' function, and output that character. (Submit for 2 points, so 5 points total).
#
# Enter integer (32 - 126):
# 99
# Enter float:
# 3.77
# Enter character:
# z
# Enter string:
# Howdy
# 99 3.77 z Howdy
# Howdy z 3.77 99
# 99 converted to a character is c
#
#  user_int = int(input('Enter integer (32 - 126):\n'))
#
# # FIXME (1): Finish reading other items into variables, then output the four values on a single line separated by a space
#
# # FIXME (2): Output the four values in reverse
#
# ## FIXME (3): Convert the integer to a characer, and output that character

# %% [markdown]
# **Hint 1**

# %%
Compare output (1 point)
When input is
99
3.77
z
Howdy
Standard output starts with
Enter integer (32 - 126):
Enter float:
Enter character:
Enter string:
99 3.77 z Howdy

# %% [markdown]
# **Hint 2**

# %%
Compare output (1 point)
When input is
35
0.01
A
Plethora
Standard output starts with
Enter integer (32 - 126):
Enter float:
Enter character:
Enter string:
35 0.01 A Plethora

# %% [markdown]
# **Hint 3**

# %%
Compare output (1 point)
When input is
99
3.77
z
Howdy
Standard output starts with
Enter integer (32 - 126):
Enter float:
Enter character:
Enter string:
99 3.77 z Howdy
Howdy z 3.77 99
(4) Compare output (1 point)
When input is
99
3.77
z
Howdy
Standard output exactly matches
Enter integer (32 - 126):
Enter float:
Enter character:
Enter string:
99 3.77 z Howdy
Howdy z 3.77 99
99 converted to a character is c
5. Compare output (1 point)
When input is
112
6.02
m
Bye
Standard output exactly matches
Enter integer (32 - 126):
Enter float:
Enter character:
Enter string:
112 6.02 m Bye
Bye m 6.02 112
112 converted to a character is p

# %% [markdown]
# **8. Program: Cooking measurement converter**

# %%
lemon_juice = float(input('Enter the amount of lemon juice (in cups): '))
water = float(input('Enter the amount of water (in cups): '))
agave_nectar = float(input('Enter the amount of agave nectar (in cups): '))
total_lemonade = lemon_juice + water + agave_nectar
print(f'The total amount of lemonade is: {total_lemonade:.2f} cups')
desired_servings = int(input('How many servings would you like to make? '))
scale = total_lemonade/desired_servings
print(f'The scale factor is: {scale:.2f}')
# Out:
# The total amount of lemonade is: 20.50 cups
# The scale factor is: 3.42

# %% [markdown]
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'{your_value:.2f}')
#
# (1) Prompt the user for the number of cups of lemon juice, water, and agave nectar needed to make lemonade. Prompt the user to specify the number of servings the recipe yields. Output the ingredients and serving size. (Submit for 2 points).
#
# Note: This zyLab outputs a newline after each user-input prompt. For convenience in the examples below, the user's input value is shown on the next line, but such values don't actually appear as output when the program runs.
#
# Enter amount of lemon juice (in cups):
# 2
# Enter amount of water (in cups):
# 16
# Enter amount of agave nectar (in cups):
# 2.5
# How many servings does this make?
# 6
#
# Lemonade ingredients - yields 6.00 servings
# 2.00 cup(s) lemon juice
# 16.00 cup(s) water
# 2.50 cup(s) agave nectar
#
# (2) Prompt the user to specify the desired number of servings. Adjust the amounts of each ingredient accordingly, and then output the ingredients and serving size. (Submit for 4 points, so 6 points total).
#
# How many servings would you like to make?
# 48
#
# Lemonade ingredients - yields 48.00 servings
# 16.00 cup(s) lemon juice
# 128.00 cup(s) water
# 20.00 cup(s) agave nectar
#
# (3) Convert the ingredient measurements from (2) to gallons. Output the ingredients and serving size. Note: There are 16 cups in a gallon. (Submit for 2 points, so 8 points total).
#
# Lemonade ingredients - yields 48.00 servings
# 1.00 gallon(s) lemon juice
# 8.00 gallon(s) water
# 1.25 gallon(s) agave nectar
#
#  lemon_juice_cups = float(input('Enter amount of lemon juice (in cups):\n'))
#
# # FIXME (1): Finish reading other items into variables, then output the three ingredients
#
# # FIXME (2): Prompt user for desired number of servings. Convert and output the ingredients
#
# # FIXME (3): Convert and output the ingredients from (2) to gallons

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
2
16
2.5
6
48
Standard output starts with
Enter amount of lemon juice (in cups):
Enter amount of water (in cups):
Enter amount of agave nectar (in cups):
How many servings does this make?

Lemonade ingredients - yields 6.00 servings
2.00 cup(s) lemon juice
16.00 cup(s) water
2.50 cup(s) agave nectar

# %% [markdown]
# **Hint 2**

# %%
Compare output (2 points)
When input is
2
16
2.5
6
48
Standard output starts with
Enter amount of lemon juice (in cups):
Enter amount of water (in cups):
Enter amount of agave nectar (in cups):
How many servings does this make?

Lemonade ingredients - yields 6.00 servings
2.00 cup(s) lemon juice
16.00 cup(s) water
2.50 cup(s) agave nectar

How many servings would you like to make?

Lemonade ingredients - yields 48.00 servings
16.00 cup(s) lemon juice
128.00 cup(s) water
20.00 cup(s) agave nectar

# %% [markdown]
# **Hint 3**

# %%
Compare output (2 points)
When input is
2
16
2.5
6
3
Standard output starts with
Enter amount of lemon juice (in cups):
Enter amount of water (in cups):
Enter amount of agave nectar (in cups):
How many servings does this make?

Lemonade ingredients - yields 6.00 servings
2.00 cup(s) lemon juice
16.00 cup(s) water
2.50 cup(s) agave nectar

How many servings would you like to make?

Lemonade ingredients - yields 3.00 servings
1.00 cup(s) lemon juice
8.00 cup(s) water
1.25 cup(s) agave nectar

(4). Compare output (2 points)
When input is
2
16
2.5
6
48
Standard output exactly matches
Enter amount of lemon juice (in cups):
Enter amount of water (in cups):
Enter amount of agave nectar (in cups):
How many servings does this make?

Lemonade ingredients - yields 6.00 servings
2.00 cup(s) lemon juice
16.00 cup(s) water
2.50 cup(s) agave nectar

How many servings would you like to make?

Lemonade ingredients - yields 48.00 servings
16.00 cup(s) lemon juice
128.00 cup(s) water
20.00 cup(s) agave nectar

Lemonade ingredients - yields 48.00 servings
1.00 gallon(s) lemon juice
8.00 gallon(s) water
1.25 gallon(s) agave nectar

# %% [markdown]
# **9. Program: Food receipt**

# %% [markdown]
# Note: When accuracy is essential, floats are not used to represent currency due to rounding and accumulation errors. Python provides several primitives specifically developed to implement financial applications. However, these topics are beyond the scope of this lab.
#
# Output each floating-point value with two digits after the decimal point, which can be achieved as follows:
# print(f'{your_value:.2f}')
#
# (1) Prompt the user to input a food item name, price, and quantity. Output an itemized receipt. (Submit for 2 points)
#
# Enter food item name:
# hot dog
# Enter item price:
# 2.00
# Enter item quantity:
# 5
#
# RECEIPT
# 5 hot dog @
# 2.00
# =
# 2.00=10.00
# Total cost: $10.00
#
# (2) Extend the program to prompt the user for a second item. Output an itemized receipt. (Submit for 2 points, so 4 points total)
#
# Enter food item name:
# hot dog
# Enter item price:
# 2.00
# Enter item quantity:
# 5
#
# RECEIPT
# 5 hot dog @
# 2.00
# =
# 2.00=10.00
# Total cost: $10.00
#
# Enter second food item name:
# ice cream
# Enter item price:
# 2.50
# Enter item quantity:
# 4
#
# RECEIPT
# 5 hot dog @
# 2.00
# =
# 2.00=10.00
# 4 ice cream @
# 2.50
# =
# 2.50=10.00
# Total cost: $20.00
#
# (3) Extend again to output a third receipt that adds a mandatory 15% gratuity to the total cost. Output the total cost, the cost of gratuity, and the grand total. (Submit for 3 points, so 7 points total)
#
# Enter food item name:
# hot dog
# Enter item price:
# 2.00
# Enter item quantity:
# 5
#
# RECEIPT
# 5 hot dog @
# 2.00
# =
# 2.00=10.00
# Total cost: $10.00
#
# Enter second food item name:
# ice cream
# Enter item price:
# 2.50
# Enter item quantity:
# 4
#
# RECEIPT
# 5 hot dog @
# 2.00
# =
# 2.00=10.00
# 4 ice cream @
# 2.50
# =
# 2.50=10.00
# Total cost: $20.00
#
# 15% gratuity: $3.00
#
# Total with tip: $23.00
#
#  item_name = input('Enter food item name:\n')
#
# # FIXME (1): Finish reading item price and quantity, then output a receipt
#
# # FIXME (2): Read in a second food item name, price, and quantity, then output a second receipt
#
# # FIXME (3): Add a gratuity and total with tip to the second receipt

# %% [markdown]
# **Hint 1**

# %%
Compare output (2 points)
When input is
hot dog
2.00
5
ice cream
2.50
4
Standard output starts with
Enter food item name:
Enter item price:
Enter item quantity:

RECEIPT
5 hot dog @
2.00
=
2.00=10.00
Total cost: $10.00

# %% [markdown]
# **Hint 2**

# %%
 Compare output (2 points)
When input is
hot dog
2.00
5
ice cream
2.50
4
Standard output starts with
Enter food item name:
Enter item price:
Enter item quantity:

RECEIPT
5 hot dog @
2.00
=
2.00=10.00
Total cost: $10.00

Enter second food item name:
Enter item price:
Enter item quantity:

RECEIPT
5 hot dog @
2.00
=
2.00=10.00
4 ice cream @
2.50
=
2.50=10.00
Total cost: $20.00

# %% [markdown]
# **Hint 3**

# %%
Compare output (2 points)
When input is
hot dog
2.00
5
ice cream
2.50
4
Standard output exactly matches
Enter food item name:
Enter item price:
Enter item quantity:

RECEIPT
5 hot dog @ 2.00=10.00

Total cost: $10.00

Enter second food item name:
Enter item price:
Enter item quantity:

RECEIPT
5 hot dog @ 2.00=10.00
4 ice cream @ 2.50=10.00
Total cost: $20.00

15% gratuity:
3.00Totalwithtip : 23.00

(4).Compare output (1 Point)
When input is
frozen lemonade
5.00
2
fried oreo
1.00
5
Standred output exactly matches
Enter food item name:
Enter item price:
Enter item quantity:

RECEIPT
2 frozen lemonade @5.00 =10.00
Total cost: $10.00

Enter second food item name:
Enter item price:
Enter item quantity:

RECEIPT
2 frozen lemonade @ 5.00 = 10.00
5 fried oreo @ 1.00 = 5.00
Total cost: $15.00

15% gratuity:
2.25Totalwithtip : 17.25
